# %% [markdown]
# <a href="https://colab.research.google.com/github/ArooshAhmad-Data/Machine-Learning-Codes/blob/master/Linear_Regression_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# using the function **make_regression**  you can create a custom (randomly initialized) regression dataset

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

X, Y = make_regression(n_features= 1, noise = 10, n_samples = 1000)

# %%
# See the results of dataset made using make_regression()
plt.xlabel("Feature -X")
plt.ylabel("Feature -Y")
plt.scatter(X,Y, s=5)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
# the fit function fit's the model i.e. trains on the model
lr.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# Gives the coefficients og the equation
# ** y = w0 + w1x **
# where w1 is the coefficient

# %%
lr.coef_
# Out:
# array([40.98033509])

# %%
lr.intercept_ # the intexcept w0
# Out:
# 0.2895834960151455

# %% [markdown]
# #### remember that input should be a 2D array
#
# if you write **lr.predict(2)** or **lr.predict([2])**, it will resultin an error

# %%
lr.predict([[2]])
# Out:
# array([82.25025367])

# %%
x_pred = lr.predict(X)

# %%
plt.scatter(X,Y, s=5, label='training')
plt.scatter(X, x_pred, s=5 , label='prediction')
plt.legend() # displays the label of the plot.
plt.xlabel("Feature - X")
plt.ylabel("Target - Y")
plt.show()

# %% [markdown]
# ## Ridge Regression
#
# It adds a penalty, so that the overfitting is tackled,
# resulting in a better model, which generalizes on the test data too.

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha = 1.)

# %%
ridge.fit(X,Y)
# Out:
# Ridge()

# %%
ridge.coef_, ridge.intercept_ # the intexcept w0
# Out:
# (array([40.93868729]), 0.2891278289342779)

# %%
ridge_pred = ridge.predict(X)

# %%
# Plotting ridge vs linear regression
# Here as no outliers, ridge and linear regression are almost identical
# Ridge(L2) regression is more robust to tackle outliers.
plt.scatter(X,Y, s=5, label="data")
plt.scatter(X,x_pred, s=5, label="linear regression")
plt.scatter(X,ridge_pred, s=5, label="ridge regression")
plt.legend()

# %%
# LASSO

# %%
# Elastic Net

# %%
# Logistic Regression
